# %% [markdown]
# <a href="https://colab.research.google.com/github/GouravRohit/Projects/blob/main/Applied_Statistics_Project(Gourav_Rohit).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %%
# import the libraries
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Module project/module 5/Assignment module 5/Superstore Marketing Data - Sheet1(Module 5).csv')
df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %%
# cleaning the dataset
df.isnull().sum()  # income column containing the 24 null values

# checking the statistical insight of the income
df['Income'].describe()

# filling null value using mean
df['Income'].fillna(df['Income'].mean(), inplace=True)
df['Income'].describe()
df.isnull().sum()
# Out:
# <ipython-input-4-bec1cf25833f>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Income'].fillna(df['Income'].mean(), inplace=True)
# Id                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# ...

# %%
# checking the datatypes
df.dtypes

# changing datatypes
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'],errors = 'coerce')

# converting catogorical values to category datatype
df['Education'] = df['Education'].astype('category')
df['Marital_Status'] = df['Marital_Status'].astype('category')

df.dtypes
# Out:
# Id                              int64
# Year_Birth                      int64
# Education                    category
# Marital_Status               category
# Income                        float64
# Kidhome                         int64
# Teenhome                        int64
# Dt_Customer            datetime64[ns]
# Recency                         int64
# MntWines                        int64
# MntFruits                       int64
# MntMeatProducts                 int64
# MntFishProducts                 int64
# MntSweetProducts                int64
# MntGoldProds                    int64
# NumDealsPurchases               int64
# NumWebPurchases                 int64
# NumCatalogPurchases             int64
# NumStorePurchases               int64
# NumWebVisitsMonth               int64
# Response                        int64
# Complain                        int64
# dtype: object

# %%
# lets create a columns name Age
df['Age'] = 2025 - df['Year_Birth']
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntSweetProducts  MntGoldProds  \
# 0  2014-06-16        0       189  ...               189           218
# 1  2014-06-15        0       464  ...                 0            37
# 2  2014-05-13        0       134  ...                 2            30
# 3         NaT        0        10  ...                 0             0
# 4         NaT        0         6  ...                 0            34
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# ...

# %%
# analysing the customer demographics
df.describe()

age_mean = df['Age'].mean()
age_median = df['Age'].median()
age_mode = df['Age'].mode()
age_variance = df['Age'].var()
age_std = df['Age'].std()
age_var = df['Age'].var()
age_range = df['Age'].max() - df['Age'].min()

income_mean = df['Income'].mean()
income_median = df['Income'].median()
income_mode = df['Income'].mode()
income_variance = df['Income'].var()
income_std = df['Income'].std()
income_var = df['Income'].var()
income_range = df['Income'].max() - df['Income'].min()



# display this statistics
print(f"Age Mean: {age_mean}, Age_median: { age_median}, Age_mode: {age_mode}, Age Variance: {age_variance} ,Standart Deviation of Age {age_std},Variance of age {age_var}, The range is {age_range}")
print("*****")
print(f"Income Mean: {income_mean}, Income_median: { income_median}, Income_mode: {income_mode} ,Income Variance: {income_variance} ,Standart Deviation of Income {income_std},Variance of income {income_var},Range of income{income_range}")
# Out:
# Age Mean: 56.19419642857143, Age_median: 55.0, Age_mode: 0    49
# Name: Age, dtype: int64, Age Variance: 143.6179207474641 ,Standart Deviation of Age 11.984069456885841,Variance of age 143.6179207474641, The range is 103
# *****
# Income Mean: 52247.25135379061, Income_median: 51741.5, Income_mode: 0    52247.251354
# Name: Income, dtype: float64 ,Income Variance: 626891287.0455537 ,Standart Deviation of Income 25037.797168392302,Variance of income 626891287.0455537,Range of income664936.0

# %%
# checking for marital status
df['Marital_Status'].value_counts()
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      480
# Divorced    232
# Widow        77
# Alone         3
# Absurd        2
# YOLO          2
# Name: count, dtype: int64

# %%
# using visualization for better understanding this discriptive statistics
import matplotlib.pyplot as plt
import seaborn as sns

# Age Distribution
plt.figure(figsize=(5,2))
sns.histplot(df['Age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Income Distribution
plt.figure(figsize=(6,2))
sns.histplot(df['Income'], bins=20, kde=True)
plt.title('Income Distribution')
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.show()

# Marital Status Distribution
plt.figure(figsize=(10,2))
sns.countplot(x='Marital_Status', data=df)
plt.title('Marital Status Distribution')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.show()

# Education Level Distribution
plt.figure(figsize=(10,2))
sns.countplot(x='Education', data=df)
plt.title('Education Level Distribution')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.show()

# %%
df.to_csv('cleaned_customer_data.csv', index=False)

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %% [markdown]
# *** Detailed Report ***
# At First I have imported the dataset using Pandas library module .read_csv method .
#
# step 1 : I caculated the Null Values useing .isnull method and fill them by using mean
#
# step 2 : I checked for the Data types for each column and fix them with the appropriate datatype
#
# step 3 I created a new variable "Age" using "Year_Birth" column and minus it with the current year
#
# step 4 : Then I caculated the the Demographics of the 'Age' , 'Income'  and 'Marital_Status' column so i can get the customers knowledge .
#
# step 5 : I used the matplotlib and seaborn to visualise the insights of the data and we can see the distribution of different variables . like age, marital status , income , education which shows about the data .

# %% [markdown]
# ***Summary*** : By using these steps I had made a strong understanding about the data .
#
# The Income Distribution is highly right skewed that mean there could be outliers in the column.
#
# The Age column is also skewed so there could be outliers but not lesser then the income columns as the distribution shows .
#
# The most of customers are married and couples in the dataset , as we can see in the graph
#
# The most of customers are graduated and we can see the least customers are belongs to the basic.

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %%
# Calculating Discriptive Statistics
mean_year_birth = df['Year_Birth'].mean()
median_year_birth = df['Year_Birth'].median()
mode_year_birth = df['Year_Birth'].mode()
variance_year_birth = df['Year_Birth'].var()
std_year_birth = df['Year_Birth'].std()

print(f"Mean Year of Birth: {mean_year_birth}, Median Year of Birth: {median_year_birth}, Mode Year of Birth: {mode_year_birth}")
print(f"Variance Year of Birth: {variance_year_birth}, Standard Deviation Year of Birth: {std_year_birth}")
# Out:
# Mean Year of Birth: 1968.8058035714287, Median Year of Birth: 1970.0, Mode Year of Birth: 0    1976
# Name: Year_Birth, dtype: int64
# Variance Year of Birth: 143.61792074746367, Standard Deviation Year of Birth: 11.984069456885823

# %%
# measuring the central tendancy
# For mean
print("Mean birth year of the customers is :", mean_year_birth )
print("Mean income of the customers is :", income_mean)
print("******")
# For median
print("Median birth year of the customers is :", median_year_birth)
print("Median income of the customers is :", income_median)
print("******")
# For mode
print("Mode of the birth year of the customers is :", mode_year_birth)
print("Mode income of the customers is :", income_mode)
# Out:
# Mean birth year of the customers is : 1968.8058035714287
# Mean income of the customers is : 52247.25135379061
# ******
# Median birth year of the customers is : 1970.0
# Median income of the customers is : 51741.5
# ******
# Mode of the birth year of the customers is : 0    1976
# Name: Year_Birth, dtype: int64
# Mode income of the customers is : 0    52247.251354
# Name: Income, dtype: float64

# %%
#

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %%
# Handling outliers
# we can use two methods to handle the outliers
# 1 = z-score  , 2 = IQR method

# %%
# Z-Score method
from scipy import stats
z_score_age = np.abs(stats.zscore(df['Income']))
z_score_income = np.abs(stats.zscore(df['Income']))

# indetifieng them
outliers_age = df[z_score_age > 3]
outliers_income = df[z_score_income > 3]

print("Outliers in Age column:")
print(outliers_age)
print('*************')
print("\nOutliers in Income column:")
print(outliers_income)
# Out:
# Outliers in Age column:
#          Id  Year_Birth   Education Marital_Status    Income  Kidhome  \
# 325    4931        1977  Graduation       Together  157146.0        0
# 497    1501        1982         PhD        Married  160803.0        0
# 527    9432        1977  Graduation       Together  666666.0        1
# 731    1503        1976         PhD       Together  162397.0        1
# 853    5336        1971      Master       Together  157733.0        1
# 1826   5555        1975  Graduation       Divorced  153924.0        0
# 1925  11181        1949         PhD        Married  156924.0        0
# 2204   8475        1973         PhD        Married  157243.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntSweetProducts  \
# 325          0  2013-04-29       13         1  ...                 1
# 497          0         NaT       21        55  ...                 3
# 527          0         NaT       23         9  ...                 1
# ...

# %%
# with IQR method
Q1_age = df['Age'].quantile(0.25)
Q3_age = df['Age'].quantile(0.75)
IQR_age = Q3_age - Q1_age

# with income
Q1_income = df['Income'].quantile(0.25)
Q3_income = df['Income'].quantile(0.75)
IQR_income = Q3_income - Q1_income

# define the outliers treshold
lower_bound_age = Q1_age - 1.5 * IQR_age
upper_bound_age = Q3_age + 1.5 * IQR_age

lower_bound_income = Q1_income - 1.5 * IQR_income
upper_bound_income = Q3_income + 1.5 * IQR_age

# identify the outliers
outliers_age_by_iqr= df[(df['Age'] < lower_bound_age) | (df['Age'] > upper_bound_age)]
outliers_income_by_iqr = df[(df['Income'] < lower_bound_income) | (df['Income'] > upper_bound_income)]

print("Outliers in Age column:")
print(outliers_age_by_iqr)
print('*************')
print("\nOutliers in Income column:")
print(outliers_income_by_iqr)
# Out:
# Outliers in Age column:
#          Id  Year_Birth Education Marital_Status   Income  Kidhome  Teenhome  \
# 513   11004        1893  2n Cycle         Single  60182.0        0         1
# 827    1150        1899       PhD       Together  83532.0        0         0
# 2233   7829        1900  2n Cycle       Divorced  36640.0        1         0
#
#      Dt_Customer  Recency  MntWines  ...  MntSweetProducts  MntGoldProds  \
# 513   2014-05-17       23         8  ...                 0             2
# 827   2013-09-26       36       755  ...                64           224
# 2233  2013-09-26       99        15  ...                 4            25
#
#       NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 513                   1                1                    0
# 827                   1                4                    6
# 2233                  1                2                    1
#
#       NumStorePurchases  NumWebVisitsMonth  Response  Complain  Age
# ...

# %%
# summarizing the result of statics
stats_summary = pd.DataFrame({
    'Variable': ['Year_Birth', 'Income'],
    'Mean': [age_mean, income_mean],
    'Median': [age_median, income_median],
    'Mode': [age_mode, income_mode],
    'Std Dev': [age_std, income_std],
    'Variance': [age_var, income_var],
    'Range': [age_range, income_range]
})

stats_summary
# Out:
#      Variable          Mean   Median  \
# 0  Year_Birth     56.194196     55.0
# 1      Income  52247.251354  51741.5
#
#                                              Mode       Std Dev      Variance  \
# 0                 0    49
# Name: Age, dtype: int64     11.984069  1.436179e+02
# 1  0    52247.251354
# Name: Income, dtype: float64  25037.797168  6.268913e+08
#
#       Range
# 0     103.0
# 1  664936.0

# %%
# Handling outliers
# removing and adjusting the outliers
df_cleaned = df[~df.index.isin(outliers_age_by_iqr.index)]
df_cleaned = df_cleaned[~df_cleaned.index.isin(outliers_income_by_iqr.index)]

# %%
df_cleaned.to_csv('cleaned_customer_data.csv', index=False)

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %%
# Calculating Probability and Expected Values
import scipy.stats as stats

# parameters for the binomial distribution
n_trials = df.shape[0]    # total customers
p_success = df['Response'].mean()   # probability of accepting the offer

# expected success
expected_success = n_trials * p_success
print(f"Expected number of successes for 'Response': {expected_success}")

# lets suppose we are calculating PMF for 100 trials
k = 100
probability_of_k_success = stats.binom.pmf(k, n_trials, p_success)
print(f"Probability of getting {k} successes: {probability_of_k_success}")
# Out:
# Expected number of successes for 'Response': 334.0
# Probability of getting 100 successes: 2.30480572103278e-57

# %%
# for cumulative prbability
cumulative_probability = stats.binom.cdf(k, n_trials, p_success)
print(f"Cumulative probability of getting {k} or fewer successes: {cumulative_probability}")
# Out:
# Cumulative probability of getting 100 or fewer successes: 3.138077121590998e-57

# %%
# Normal Distribution
# calculating parameters
# for income
print(f"Mean income: {income_mean}")
print(f"Standard deviation of income: {income_std}")

# for Age
print(f"Mean age: {age_mean}")
print(f"Standard deviation of age: {age_std}")
# Out:
# Mean income: 52247.25135379061
# Standard deviation of income: 25037.797168392302
# Mean age: 56.19419642857143
# Standard deviation of age: 11.984069456885841

# %%
# calculating the probabilities
# let suppose the threshold value of the income is 50000 and we want to get the probabily of income less then the threshold value
threshold_income = 50000
probability_less_then_threshold = stats.norm.cdf(threshold_income , income_mean,income_std)
print(f"Probability of income being less than {threshold_income}: {probability_less_then_threshold}")

# probability of age is between 30 to 50
lower_age_threshold = 30
upper_age_threshold = 50
probability_age_between_thresholds = stats.norm.cdf(upper_age_threshold, age_mean, age_std) - stats.norm.cdf(lower_age_threshold, age_mean, age_std)
print(f"Probability of age being between {lower_age_threshold} and {upper_age_threshold}: {probability_age_between_thresholds}")
# Out:
# Probability of income being less than 50000: 0.46424121028848647
# Probability of age being between 30 and 50: 0.28820683411568754

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %%
# We caculated ,How the Response is connected to the Income and also caculated the PMF for getting the better understanding about the dependancy (Binomal )
# Same as  we caculated the Age feature and its Distribution (Normal) . We approached the PMF and CDF for better understanding about the feature

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %%
# Lets caculate the correlation for get the relationship between the variables
numeric_columns = df[['Income', 'MntWines', 'MntFruits', 'MntMeatProducts','MntFishProducts', 'MntSweetProducts', 'MntGoldProds']]
correlation_matrix =numeric_columns.corr()
correlation_matrix
# Out:
#                     Income  MntWines  MntFruits  MntMeatProducts  \
# Income            1.000000  0.576789   0.428747         0.577802
# MntWines          0.576789  1.000000   0.389637         0.562667
# MntFruits         0.428747  0.389637   1.000000         0.543105
# MntMeatProducts   0.577802  0.562667   0.543105         1.000000
# MntFishProducts   0.437497  0.399753   0.594804         0.568402
# MntSweetProducts  0.436162  0.386581   0.567164         0.523846
# MntGoldProds      0.321978  0.387516   0.392995         0.350609
#
#                   MntFishProducts  MntSweetProducts  MntGoldProds
# Income                   0.437497          0.436162      0.321978
# MntWines                 0.399753          0.386581      0.387516
# MntFruits                0.594804          0.567164      0.392995
# MntMeatProducts          0.568402          0.523846      0.350609
# MntFishProducts          1.000000          0.579870      0.422875
# ...

# %%
# Spending Pattern Demographics
# lets use the group by for better understanding that how the spending is diffrent by the customers demographics (Age,Education,Marital_Stats)
spending_by_age = df.groupby('Age')[['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']].mean()
spending_by_education = df.groupby('Education')[['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']].mean()
spending_by_marital_status = df.groupby('Marital_Status')[['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']].mean()

print("Spending by Age:")
print(spending_by_age)
print("\nSpending by Education:")
print(spending_by_education)
print("\nSpending by Marital Status:")
print(spending_by_marital_status)
# Out:
# Spending by Age:
#         MntWines   MntFruits  MntMeatProducts  MntFishProducts  \
# Age
# 29      1.500000    9.000000         8.000000         9.000000
# 30    284.200000   19.800000       323.000000        50.400000
# 31    659.000000   33.333333       592.000000       112.000000
# 32    391.200000   86.400000       344.000000       160.000000
# 33    253.000000   34.153846       282.615385        36.615385
# 34    549.200000   41.333333       340.733333        54.200000
# 35    190.833333   35.944444       213.333333        30.555556
# 36    207.900000   24.133333       142.166667        34.933333
# 37    301.448276   43.275862       243.448276        44.793103
# 38    289.592593   31.407407       180.037037        42.518519
# 39    204.690476   24.095238       184.452381        31.714286
# 40    162.187500   18.187500       117.281250        24.750000
# 41    159.710526   22.078947       102.026316        29.315789
# ...

# %%
# We can use visualization for better understanding
# spending by education
spending_by_education.plot(kind='bar')
plt.title('Spending by Education')
plt.xlabel('Education')
plt.ylabel('Average Spending')
plt.show()

# spending by marital status
spending_by_marital_status.plot(kind='bar')
plt.title('Spending by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Average Spending')
plt.show()

# spending by age
spending_by_age.plot(kind='bar', figsize=(12, 8))
plt.title('Average Spending by Age')
plt.xlabel('Age')
plt.ylabel('Average Spending')
plt.show()

# %%
# Customer Segmentation
# we can use the clutering technique for the segmentation
# K-Means
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# dataset for clustering
variables = df[['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']]

# standardize the scaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(variables)     # scaling for the data to get a better result

# Applying the K-Means Clustering
kmeans = KMeans(n_clusters = 4,random_state = 42)   # total 4 clusters we are making here
df['Cluster'] = kmeans.fit_predict(scaled_data)

# Clusters Center
clusters_centroids = scaler.inverse_transform(kmeans.cluster_centers_)      # inverse_transform will convert back to the starting scale of the data and give the exact result
print( "Clusters Centers ", clusters_centroids)
# Out:
# Clusters Centers  [[ 79.9684466    6.04692557  32.69983819   8.45954693   6.03398058
#    15.76779935]
#  [746.92105263  46.57518797 553.5112782   70.30075188  51.18796992
#    46.70300752]
#  [476.6744186   95.77408638 385.93355482 132.99335548  98.16943522
#    97.64119601]
#  [548.77574371  23.40045767 160.52860412  34.02745995  22.87871854
#    85.37070938]]

# %%
# lets visualize the clustered data
import matplotlib.pyplot as plt
import seaborn as sns

# for income and wines
plt.figure(figsize = (6,6))
sns.scatterplot(data = df, x = 'Income',y = 'MntWines',hue = 'Cluster',palette= 'viridis')
plt.title('Customers Segmentation On The Bases Of Income And Wine Spending')
plt.xlabel('Income')
plt.ylabel('MntWines')
plt.show()

# for income and fruits
plt.figure(figsize = (6,6))
sns.scatterplot(data = df, x = 'Income',y = 'MntFruits',hue = 'Cluster',palette= 'viridis')
plt.title('Customers Segmentation On The Bases Of Income And Fruits Spending')
plt.xlabel('Income')
plt.ylabel('MntFruits')
plt.show()

# for income and meat products
plt.figure(figsize = (6,6))
sns.scatterplot(data = df, x = 'Income',y = 'MntMeatProducts',hue = 'Cluster',palette= 'viridis')
plt.title('Customers Segmentation On The Bases Of Income And Meat Products Spending')
plt.xlabel('Income')
plt.ylabel('MntMeatProducts')
plt.show()

# for income and fish products
plt.figure(figsize = (6,6))
sns.scatterplot(data = df, x = 'Income',y = 'MntFishProducts',hue = 'Cluster',palette= 'viridis')
plt.title('Customers Segmentation On The Bases Of Income And Fish Spending')
plt.xlabel('Income')
plt.ylabel('MntFishProducts')
plt.show()

# for income and sweets products
plt.figure(figsize = (6,6))
sns.scatterplot(data = df, x = 'Income',y = 'MntSweetProducts',hue = 'Cluster',palette= 'viridis')
plt.title('Customers Segmentation On The Bases Of Income And Sweets Spending')
plt.xlabel('Income')
plt.ylabel('MntSweetProducts')
plt.show()

# for income and gold products
plt.figure(figsize = (6,6))
sns.scatterplot(data = df, x = 'Income',y = 'MntGoldProds',hue = 'Cluster',palette= 'viridis')
plt.title('Customers Segmentation On The Bases Of Income And Gold Products Spending')
plt.xlabel('Income')
plt.ylabel('MntGoldProds')
plt.show()

# %%
# Data type of clusters
df['Cluster'].dtypes
# Out:
# dtype('int32')

# %%
# lets caculate the numerical columns
numerical_columns = ['Income', 'MntWines', 'MntFruits', 'MntMeatProducts',
                      'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']

# for each numerical column the mean value according to the cluster
cluster_df = df.groupby('Cluster')[numerical_columns].mean()
cluster_df
# Out:
#                Income    MntWines  MntFruits  MntMeatProducts  \
# Cluster
# 0        38845.091844   79.968447   6.046926        32.699838
# 1        77243.465241  746.921053  46.575188       553.511278
# 2        72450.828913  476.674419  95.774086       385.933555
# 3        61022.536057  548.775744  23.400458       160.528604
#
#          MntFishProducts  MntSweetProducts  MntGoldProds
# Cluster
# 0               8.459547          6.033981     15.767799
# 1              70.300752         51.187970     46.703008
# 2             132.993355         98.169435     97.641196
# 3              34.027460         22.878719     85.370709

# %%
# lets check the most frequent category for categorical variables
mode_education = df.groupby('Cluster')['Education'].agg(lambda x: x.mode()[0])
mode_marital_status = df.groupby('Cluster')['Marital_Status'].agg(lambda x: x.mode()[0])

# adding them into the cluster dataframe dataset
cluster_df['Education']= mode_education
cluster_df['Marital_Status'] = mode_marital_status

cluster_df
# Out:
#                Income    MntWines  MntFruits  MntMeatProducts  \
# Cluster
# 0        38845.091844   79.968447   6.046926        32.699838
# 1        77243.465241  746.921053  46.575188       553.511278
# 2        72450.828913  476.674419  95.774086       385.933555
# 3        61022.536057  548.775744  23.400458       160.528604
#
#          MntFishProducts  MntSweetProducts  MntGoldProds   Education  \
# Cluster
# 0               8.459547          6.033981     15.767799  Graduation
# 1              70.300752         51.187970     46.703008  Graduation
# 2             132.993355         98.169435     97.641196  Graduation
# 3              34.027460         22.878719     85.370709  Graduation
#
#         Marital_Status
# Cluster
# 0              Married
# 1              Married
# 2              Married
# 3              Married

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %% [markdown]
# **Key Insights**
#
# The most of the moderatly correlated with customers income.
#
# By the demographics we can see the purchasing behaviour of the customers accordingly the education they belongs to , age, and marital status.
#
# Most of the customers are prefering the wines in each senario.
#
# **Segmentation**
#
# We used the K-Means clustering for sengmentation , for this first we scaled the data using Standardscaler() then we did the clustering for better interpretation.
#
# We took the n_cluster = 4 randomly ,  but in future with the real data we can use albow method to decide the number of clusters ,and then we predict by using the scaled data , agin we invers the scalling for get the exact data what we scaled before .
#
# Then we visualise it and we can see the dependancy on the income .
#
# We created a dataframe where we can store the data belongs to diffrent clusters and we can see the patterns

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %%
# lets visualise the clusters data to get better understanding of the sengmentation
import matplotlib.pyplot as plt

# customers in each cluster
customers_in_cluster = df['Cluster'].value_counts()

# pie chart
plt.figure(figsize=(4,3))
plt.pie(customers_in_cluster, labels=customers_in_cluster.index, autopct='%1.1f%%', startangle=90)
plt.title('Customers in Each Cluster')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py'>

# %%
# average spending according to clusters
cluster_df.plot(kind = 'bar')
plt.title('Average Spending by Cluster')
plt.xlabel('Cluster')
plt.ylabel('Average Spending')
plt.show()

# income has lots of outliers lets visualise this without using income column
cluster_without_income = cluster_df.drop(columns = 'Income')
cluster_without_income.plot(kind = 'bar')
plt.title('Average Spending by Cluster')
plt.xlabel('Cluster')
plt.ylabel('Average Spending')
plt.show()

# %%
# lets check the distribution of the education and marital stats of the customers
education_counts = df.groupby('Cluster')['Education'].value_counts()
marital_status_counts = df.groupby('Cluster')['Marital_Status'].value_counts()

# for education
plt.figure(figsize=(10, 6))
education_counts.unstack().plot(kind='bar')
plt.title('Education Distribution by Cluster')
plt.xlabel('Cluster')
plt.ylabel('Count')
plt.legend(title='Education')
plt.show()

# for marital_stats
plt.figure(figsize=(10, 6))
marital_status_counts.unstack().plot(kind='bar')
plt.title('Marital Status Distribution by Cluster')
plt.xlabel('Cluster')
plt.ylabel('Count')
plt.legend(title='Marital Status')
plt.show()

# %% [markdown]
# ## Bonus Task - Geogebra Experiment

# %% [markdown]
# Here's the link to an intriguing GeoGebra experiment: [GeoGebra Experiment Link](https://www.geogebra.org/m/LZbwMZtJ)
#
# This experiment lets you simulate coin flips as per your preferences and specifications!
#
# Your task involves recording a video where you'll explain the concept of the **Law of Large Numbers** using this experiment. Dive further into the experience by adjusting the number of coins and exploring varying coin biases. 🪙📹🔍
